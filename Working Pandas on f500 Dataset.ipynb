# %%
import pandas as pd

# %% [markdown]
# # SIMD
# ##Single instruction for multiple data

# %%
f500=pd.read_csv("f500.csv")

# %%
f500
# Out:
#                             company  rank  revenues  revenue_change  profits  \
# 0                           Walmart     1    485873             0.8  13643.0
# 1                        State Grid     2    315199            -4.4   9571.3
# 2                     Sinopec Group     3    267518            -9.1   1257.9
# 3          China National Petroleum     4    262573           -12.3   1867.5
# 4                      Toyota Motor     5    254694             7.7  16899.3
# ..                              ...   ...       ...             ...      ...
# 495  Teva Pharmaceutical Industries   496     21903            11.5    329.0
# 496        New China Life Insurance   497     21796           -13.3    743.9
# 497       Wm. Morrison Supermarkets   498     21741           -11.3    406.4
# 498                             TUI   499     21655            -5.5   1151.7
# 499                      AutoNation   500     21609             3.6    430.5
#
# ...

# %%
#.shape and .dtypes (for providing information)

# %%
f500.shape
# Out:
# (500, 17)

# %%
f500.dtypes
# Out:
# company                      object
# rank                          int64
# revenues                      int64
# revenue_change              float64
# profits                     float64
# assets                        int64
# profit_change               float64
# ceo                          object
# industry                     object
# sector                       object
# previous_rank                 int64
# country                      object
# hq_location                  object
# website                      object
# years_on_global_500_list      int64
# employees                     int64
# total_stockholder_equity      int64
# dtype: object

# %%
f500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   company                   500 non-null    object
#  1   rank                      500 non-null    int64
#  2   revenues                  500 non-null    int64
#  3   revenue_change            498 non-null    float64
#  4   profits                   499 non-null    float64
#  5   assets                    500 non-null    int64
#  6   profit_change             436 non-null    float64
#  7   ceo                       500 non-null    object
#  8   industry                  500 non-null    object
#  9   sector                    500 non-null    object
#  10  previous_rank             500 non-null    int64
#  11  country                   500 non-null    object
#  12  hq_location               500 non-null    object
# ...

# %%
f500.describe()
# Out:
#              rank       revenues  revenue_change       profits        assets  \
# count  500.000000     500.000000      498.000000    499.000000  5.000000e+02
# mean   250.500000   55416.358000        4.538353   3055.203206  2.436323e+05
# std    144.481833   45725.478963       28.549067   5171.981071  4.851937e+05
# min      1.000000   21609.000000      -67.300000 -13038.000000  3.717000e+03
# 25%    125.750000   29003.000000       -5.900000    556.950000  3.658850e+04
# 50%    250.500000   40236.000000        0.550000   1761.600000  7.326150e+04
# 75%    375.250000   63926.750000        6.975000   3954.000000  1.805640e+05
# max    500.000000  485873.000000      442.300000  45687.000000  3.473238e+06
#
#        profit_change  previous_rank  years_on_global_500_list     employees  \
# count     436.000000     500.000000                500.000000  5.000000e+02
# mean       24.152752     222.134000                 15.036000  1.339983e+05
# ...

# %%
f500.head(10)
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
# 5                Volkswagen     6    240264             1.5   5937.3  432116
# 6         Royal Dutch Shell     7    240033           -11.8   4575.0  411275
# 7        Berkshire Hathaway     8    223604             6.1  24074.0  620854
# 8                     Apple     9    215639            -7.7  45687.0  321686
# 9               Exxon Mobil    10    205004           -16.7   7840.0  330314
#
#    profit_change                  ceo  \
# 0           -7.2  C. Douglas McMillon
# 1           -6.2              Kou Wei
# ...

# %%
f500.tail(10)
# Out:
#                                    company  rank  revenues  revenue_change  \
# 490                          National Grid   491     22036            -3.2
# 491                         Dollar General   492     21987             7.9
# 492                         Telecom Italia   493     21941           -17.4
# 493               Xiamen ITG Holding Group   494     21930            34.3
# 494  Xinjiang Guanghui Industry Investment   495     21919            31.1
# 495         Teva Pharmaceutical Industries   496     21903            11.5
# 496               New China Life Insurance   497     21796           -13.3
# 497              Wm. Morrison Supermarkets   498     21741           -11.3
# 498                                    TUI   499     21655            -5.5
# 499                             AutoNation   500     21609             3.6
#
#      profits  assets  profit_change                 ceo  \
# 490  10150.6   82310          160.2      John Pettigrew
# ...

# %%
#pd.options.display.max_rows = None

# %%
f500["company"]
# Out:
# 0                             Walmart
# 1                          State Grid
# 2                       Sinopec Group
# 3            China National Petroleum
# 4                        Toyota Motor
#                     ...
# 495    Teva Pharmaceutical Industries
# 496          New China Life Insurance
# 497         Wm. Morrison Supermarkets
# 498                               TUI
# 499                        AutoNation
# Name: company, Length: 500, dtype: object

# %%
f500["company"].head()
# Out:
# 0                     Walmart
# 1                  State Grid
# 2               Sinopec Group
# 3    China National Petroleum
# 4                Toyota Motor
# Name: company, dtype: object

# %%
f500[["company","rank","ceo"]]
# Out:
#                             company  rank                  ceo
# 0                           Walmart     1  C. Douglas McMillon
# 1                        State Grid     2              Kou Wei
# 2                     Sinopec Group     3            Wang Yupu
# 3          China National Petroleum     4        Zhang Jianhua
# 4                      Toyota Motor     5          Akio Toyoda
# ..                              ...   ...                  ...
# 495  Teva Pharmaceutical Industries   496    Yitzhak Peterburg
# 496        New China Life Insurance   497             Wan Feng
# 497       Wm. Morrison Supermarkets   498       David T. Potts
# 498                             TUI   499    Friedrich Joussen
# 499                      AutoNation   500   Michael J. Jackson
#
# [500 rows x 3 columns]

# %%
f500.columns
# Out:
# Index(['company', 'rank', 'revenues', 'revenue_change', 'profits', 'assets',
#        'profit_change', 'ceo', 'industry', 'sector', 'previous_rank',
#        'country', 'hq_location', 'website', 'years_on_global_500_list',
#        'employees', 'total_stockholder_equity'],
#       dtype='object')

# %%
# iloc = when will have integer indexing
# loc = when will have lebelling indexing

# %%
f500.iloc[10:15] # slicing
# Out:
#                 company  rank  revenues  revenue_change  profits  assets  \
# 10             McKesson    11    198533             3.1   5070.0   60969
# 11                   BP    12    186606           -17.4    115.0  263316
# 12   UnitedHealth Group    13    184840            17.7   7017.0  122810
# 13           CVS Health    14    177526            15.8   5317.0   94462
# 14  Samsung Electronics    15    173957            -2.0  19316.5  217104
#
#     profit_change                 ceo  \
# 10          124.5  John H. Hammergren
# 11            NaN    Robert W. Dudley
# 12           20.7  Stephen J. Hemsley
# 13            1.5      Larry J. Merlo
# 14           16.8        Oh-Hyun Kwon
#
#                                     industry       sector  previous_rank  \
# 10                  Wholesalers: Health Care  Wholesalers             12
# 11                        Petroleum Refining       Energy             10
# ...

# %%
f500.iloc[10:15,0:4]
# Out:
#                 company  rank  revenues  revenue_change
# 10             McKesson    11    198533             3.1
# 11                   BP    12    186606           -17.4
# 12   UnitedHealth Group    13    184840            17.7
# 13           CVS Health    14    177526            15.8
# 14  Samsung Electronics    15    173957            -2.0

# %%
f500.loc[10:15,"company":"ceo"]
# Out:
#                 company  rank  revenues  revenue_change  profits  assets  \
# 10             McKesson    11    198533             3.1   5070.0   60969
# 11                   BP    12    186606           -17.4    115.0  263316
# 12   UnitedHealth Group    13    184840            17.7   7017.0  122810
# 13           CVS Health    14    177526            15.8   5317.0   94462
# 14  Samsung Electronics    15    173957            -2.0  19316.5  217104
# 15             Glencore    16    173883             2.0   1379.0  124600
#
#     profit_change                 ceo
# 10          124.5  John H. Hammergren
# 11            NaN    Robert W. Dudley
# 12           20.7  Stephen J. Hemsley
# 13            1.5      Larry J. Merlo
# 14           16.8        Oh-Hyun Kwon
# 15            NaN     Ivan Glasenberg

# %%
f500.loc[[10,12],["company","revenues"]]
# Out:
#                company  revenues
# 10            McKesson    198533
# 12  UnitedHealth Group    184840

# %%
f500.loc[12,"revenues"]
# Out:
# 184840

# %%
f500.iloc[13,2] +=100

# %%
f500.iloc[13,2]
# Out:
# 177626

# %%
f500.iloc[[13,19],[0,4]]
# Out:
#        company  profits
# 13  CVS Health   5317.0
# 19  EXOR Group    651.3

# %%
f500["country"].value_counts() #value_counts its use for generate any kind of frequency
# Out:
# USA             132
# China           109
# Japan            51
# Germany          29
# France           29
# Britain          24
# South Korea      15
# Netherlands      14
# Switzerland      14
# Canada           11
# Spain             9
# Italy             7
# Australia         7
# India             7
# Brazil            7
# Taiwan            6
# Russia            4
# Ireland           4
# Singapore         3
# Sweden            3
# Mexico            2
# Denmark           1
# Finland           1
# Belgium           1
# Venezuela         1
# Israel            1
# Norway            1
# Thailand          1
# Indonesia         1
# Turkey            1
# U.A.E             1
# Saudi Arabia      1
# Malaysia          1
# Luxembourg        1
# Name: country, dtype: int64

# %%
boolean = f500["country"] == "India"
f500.loc[boolean]
# Out:
#                  company  rank  revenues  revenue_change  profits  assets  \
# 167           Indian Oil   168     53562            -2.1   2960.0   42132
# 202  Reliance Industries   203     46931             8.0   4458.9  108856
# 216  State Bank of India   217     44533             6.8     36.0  530590
# 246          Tata Motors   247     40329            -4.2   1111.6   42162
# 294       Rajesh Exports   295     36114            43.1    185.8    3717
# 359     Bharat Petroleum   360     30316             4.2   1300.5   16801
# 383  Hindustan Petroleum   384     28166            -2.3   1228.1   12370
#
#      profit_change                     ceo                       industry  \
# 167           72.7            Sanjiv Singh             Petroleum Refining
# 202            5.6        Mukesh D. Ambani             Petroleum Refining
# 216          -98.1  Arundhati Bhattacharya  Banks: Commercial and Savings
# 246          -34.0        Guenter Butschek       Motor Vehicles and Parts
# ...

# %%
#pd.options.display.max_rows = None

# %%
boolean=f500["country"] == "USA", "company"  #we can use this function as well its up to you. f500.loc[f500["country"] == "USA","company"]
f500.loc[boolean]
# Out:
# 0                 Walmart
# 7      Berkshire Hathaway
# 8                   Apple
# 9             Exxon Mobil
# 10               McKesson
#               ...
# 480          U.S. Bancorp
# 482                 Aflac
# 488        Sears Holdings
# 491        Dollar General
# 499            AutoNation
# Name: company, Length: 132, dtype: object
